# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # 1. Load the dataset into a pandas dataframe. Name the variable as “survey”.

# %%
survey = pd.read_excel("Sample Survey (1).xlsx",sheet_name="Data")

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1      2020-08-24       Rural               12th Pass
# 1               2      2020-08-24       Rural                Graduate
# 2               3      2020-08-24       Rural                Graduate
# 3               4      2020-08-24       Urban                Graduate
# 4               5      2020-08-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863      2020-09-01       Rural               10th Pass
# 6863         6864      2020-09-01       Rural                Graduate
# 6864         6865      2020-09-01       Urban                Graduate
# 6865         6866      2020-09-01       Rural  Professional Education
# 6866         6867      2020-09-01       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %% [markdown]
# # 2.How many samples were collected on each day?

# %%
#checking for null values
survey.isnull().sum()
# Out:
# response_id         0
# collection_date     0
# urban_rural         0
# education           0
# income              0
# Vote_Now            0
# Past_Vote           0
# CM_satisfaction     0
# MLA_satisfaction    0
# age                 0
# gender              0
# assembly_no         0
# category            0
# weight              0
# dtype: int64

# %%
#checking for duplicates value
len(survey[survey.duplicated() == True])  #no duplicate rowns
# Out:
# 0

# %% [markdown]
# # Samples collected on each day

# %%
survey.groupby(['collection_date'])['response_id'].count()
# Out:
# collection_date
# 2020-08-24    1479
# 2020-08-25     998
# 2020-08-26     598
# 2020-08-27     665
# 2020-08-28     761
# 2020-08-29     620
# 2020-08-30     582
# 2020-08-31     557
# 2020-09-01     607
# Name: response_id, dtype: int64

# %% [markdown]
# # 3.What proportion of the total respondents were aged less than 45

# %%
#replace wrong entry with correct one
survey['age'] = survey['age'].replace(['24ko'],'24')

# %%
#Converting age datatype as object to int
survey['age'] = survey["age"].astype(str).astype(int)

# %%
#checking datatype of each feature
survey.dtypes
# Out:
# response_id                  int64
# collection_date     datetime64[ns]
# urban_rural                 object
# education                   object
# income                      object
# Vote_Now                    object
# Past_Vote                   object
# CM_satisfaction             object
# MLA_satisfaction            object
# age                          int32
# gender                      object
# assembly_no                  int64
# category                    object
# weight                     float64
# dtype: object

# %%
#we can see above datatype of age is changed to int

# %%
#getting those values  where age < 45
survey[survey['age']<45]
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1      2020-08-24       Rural               12th Pass
# 1               2      2020-08-24       Rural                Graduate
# 2               3      2020-08-24       Rural                Graduate
# 3               4      2020-08-24       Urban                Graduate
# 4               5      2020-08-24       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863      2020-09-01       Rural               10th Pass
# 6863         6864      2020-09-01       Rural                Graduate
# 6864         6865      2020-09-01       Urban                Graduate
# 6865         6866      2020-09-01       Rural  Professional Education
# 6866         6867      2020-09-01       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# ...

# %%
proportion = len(survey[survey['age']<45]) / len(survey['age'])

# %% [markdown]
# # Proportion of respondent lesss than age of 45 years

# %%
proportion
# Out:
# 0.9318479685452162

# %% [markdown]
# # From the above value we can say that more than 90% voters are young voters

# %% [markdown]
# # 4.Create a new column in the dataframe “age_group”. This column should contain the age group the respondent belongs to. The age groups are 18-25, 25-40, 40-55 and 55+.

# %%
#finding the maximum value
age_group = survey['age']
max_value = age_group.max()
max_value
# Out:
# 99

# %%
bins=[17,25,40,55,99]
group=['18-25','25-40','40-55','55+']
survey['age_group']=pd.cut(survey['age'],bins,labels=group)

# %%
survey['age_group'].value_counts()
# Out:
# 25-40    3423
# 18-25    2692
# 40-55     644
# 55+       108
# Name: age_group, dtype: int64

# %%
survey.dtypes
# Out:
# response_id                  int64
# collection_date     datetime64[ns]
# urban_rural                 object
# education                   object
# income                      object
# Vote_Now                    object
# Past_Vote                   object
# CM_satisfaction             object
# MLA_satisfaction            object
# age                          int32
# gender                      object
# assembly_no                  int64
# category                    object
# weight                     float64
# age_group                 category
# dtype: object

# %% [markdown]
# # Reordering the columns as asked in the questions arrange  age with age_group

# %%
survey = survey[['response_id','age','age_group','collection_date','urban_rural','education' ,'income','Vote_Now','Past_Vote','CM_satisfaction','MLA_satisfaction','gender','assembly_no','category','weight']]

# %%
survey
# Out:
#       response_id  age age_group collection_date urban_rural  \
# 0               1   26     25-40      2020-08-24       Rural
# 1               2   34     25-40      2020-08-24       Rural
# 2               3   25     18-25      2020-08-24       Rural
# 3               4   36     25-40      2020-08-24       Urban
# 4               5   22     18-25      2020-08-24       Rural
# ...           ...  ...       ...             ...         ...
# 6862         6863   25     18-25      2020-09-01       Rural
# 6863         6864   30     25-40      2020-09-01       Rural
# 6864         6865   20     18-25      2020-09-01       Urban
# 6865         6866   23     18-25      2020-09-01       Rural
# 6866         6867   33     25-40      2020-09-01       Rural
#
#                    education               income Vote_Now     Past_Vote  \
# 0                  12th Pass  ₹ 30,000 - ₹ 50,000      BJP           BJP
# 1                   Graduate  ₹ 20,000 - ₹ 30,000     RLSP         JD(U)
# ...

# %% [markdown]
# # 5.How many samples were collected for each age-group? Which age-group had the most samples?

# %%
survey['age_group'].value_counts()
# Out:
# 25-40    3423
# 18-25    2692
# 40-55     644
# 55+       108
# Name: age_group, dtype: int64

# %% [markdown]
# # 25-40 age group has the highest number of sample values

# %% [markdown]
# # 6.What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions

# %%
survey['Vote_Now'].value_counts(normalize=True)
# Out:
# BJP           0.344692
# RJD           0.290666
# JD(U)         0.076598
# NOTA          0.066696
# JAP(L)        0.045580
# Plurals       0.031600
# INC           0.031455
# Undecided     0.023882
# RJJP          0.020679
# LJP           0.014854
# Others        0.012669
# RLSP          0.011941
# Left Front    0.011504
# AIMIM         0.005388
# VIP           0.004077
# AAP           0.003932
# BSP           0.002184
# HAM           0.001602
# Name: Vote_Now, dtype: float64

# %%
survey['Past_Vote'].value_counts(normalize=True)
# Out:
# BJP             0.411097
# JD(U)           0.200087
# RJD             0.152468
# Did not vote    0.117082
# INC             0.031018
# NOTA            0.024319
# Others          0.019222
# LJP             0.018203
# HAM             0.007281
# RLSP            0.007136
# JAP(L)          0.006116
# Left Front      0.004369
# BSP             0.001311
# VIP             0.000291
# Name: Past_Vote, dtype: float64

# %% [markdown]
# # Proportion of RJD in Vote_Now is 0.290666   and RJD in 'Past_Vote' is 0.152468

# %% [markdown]
# # 7.For each day of sample collection, determine the proportion of respondents who were fully satisfied with the performance of the CM. So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied, then our answer for that day would be 0.3.

# %%
survey['age_group'].value_counts()
# Out:
# 25-40    3423
# 18-25    2692
# 40-55     644
# 55+       108
# Name: age_group, dtype: int64

# %%
survey_fully_satisfied = survey[survey["MLA_satisfaction"] == "Fully Satisfied"]

# %%
survey_1=survey_fully_satisfied[['collection_date', 'response_id']]

# %% [markdown]
# # For each day of sample collection, the proportion of respondents who were fully satisfied with the performance of the CM

# %%
survey_1['collection_date'].value_counts(normalize=True)
# Out:
# 2020-08-24    0.223881
# 2020-08-28    0.116418
# 2020-08-25    0.107463
# 2020-08-29    0.105970
# 2020-08-26    0.092537
# 2020-08-30    0.092537
# 2020-08-27    0.091045
# 2020-08-31    0.088060
# 2020-09-01    0.082090
# Name: collection_date, dtype: float64

# %% [markdown]
# # 8.In a similar fashion create a day-wise proportion of respondents that opted fullydissatisfied with their MLA. Create a line plot of the result with date on x-axis and proportions on the y-axis.

# %%
survey['age_group'].value_counts()
# Out:
# 25-40    3423
# 18-25    2692
# 40-55     644
# 55+       108
# Name: age_group, dtype: int64

# %%
#TAKING  columns from dataframe where CM_satisfaction is fully dissatisfied
survey_1=survey[survey['CM_satisfaction']=='Fully Dissatisfied']

# %%
df2=survey_1[['collection_date', 'response_id']]
df2['collection_date'].value_counts(normalize=True)
# Out:
# 2020-08-24    0.213147
# 2020-08-25    0.143758
# 2020-08-28    0.115870
# 2020-08-27    0.097610
# 2020-08-29    0.093958
# 2020-08-26    0.085657
# 2020-09-01    0.083665
# 2020-08-31    0.083333
# 2020-08-30    0.083001
# Name: collection_date, dtype: float64

# %%
plt.figure(1)
df2['collection_date'].value_counts(normalize=True).plot.line(figsize=(10,5), title= 'Proportion of respondent fully satisfied with Performance of CM vs Days ',xlabel="Date",ylabel='Proportions ',marker='o',color='red')

# %% [markdown]
# # 9.Create a pivot-table (or crosstab) with index as Past_Vote, Column as Vote_Now and cell values as the count of samples.

# %%
survey.groupby(['Past_Vote','Vote_Now'])['response_id'].count().unstack()
# Out:
# Vote_Now      AAP  AIMIM     BJP  BSP  HAM   INC  JAP(L)  JD(U)   LJP  \
# Past_Vote
# BJP           7.0    1.0  1630.0  3.0  5.0  42.0   101.0  110.0  44.0
# BSP           NaN    1.0     2.0  5.0  NaN   1.0     NaN    NaN   NaN
# Did not vote  8.0    5.0   231.0  2.0  1.0  22.0    41.0   69.0  10.0
# HAM           2.0    NaN    25.0  NaN  1.0   NaN     3.0    2.0   2.0
# INC           NaN    6.0     6.0  NaN  NaN  57.0    10.0    9.0   NaN
# JAP(L)        NaN    NaN     4.0  NaN  NaN   NaN    35.0    NaN   NaN
# JD(U)         6.0   10.0   254.0  2.0  2.0  45.0    72.0  279.0  29.0
# LJP           NaN    NaN    76.0  1.0  NaN   4.0     3.0    6.0   9.0
# Left Front    NaN    1.0     2.0  NaN  NaN   1.0     NaN    NaN   NaN
# NOTA          NaN    1.0    29.0  1.0  NaN   9.0     7.0    7.0   3.0
# Others        1.0    5.0    45.0  1.0  1.0   4.0     7.0    4.0   1.0
# RJD           3.0    7.0    46.0  NaN  1.0  31.0    31.0   39.0   4.0
# ...

# %% [markdown]
# # 10. Repeat the above question with the cell values as the sum of “weight”.

# %%
survey.groupby(['Past_Vote','Vote_Now'])['weight'].sum().unstack()
# Out:
# Vote_Now            AAP      AIMIM          BJP        BSP        HAM  \
# Past_Vote
# BJP            4.807335   0.349996  1049.344112   0.452551  10.171283
# BSP                 NaN   1.654731     5.174487  32.010277        NaN
# Did not vote   8.865896   5.379527   114.203906   3.329611   2.497170
# HAM            0.312607        NaN    25.348884        NaN   1.648856
# INC                 NaN  11.105958     1.642875        NaN        NaN
# JAP(L)              NaN        NaN     6.512846        NaN        NaN
# JD(U)         12.457216  29.198610   156.243100  11.005903   2.639574
# LJP                 NaN        NaN    85.010450   2.481377        NaN
# Left Front          NaN   2.298223     0.209586        NaN        NaN
# NOTA                NaN   1.061204    12.685435   0.051485        NaN
# Others        13.661335  21.212705    34.866218   0.684568   1.505864
# RJD            5.515847  24.149369    32.285093        NaN   0.960400
# ...

# %% [markdown]
# # 11.Create a dataframe by performing a group by over age_group and calculate the count of total samples under each age_group.

# %%
#creating dataframe
t5=survey.groupby( [ "age_group"] ).size().to_frame(name = 'count').reset_index()

# %% [markdown]
# # 12.Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now.

# %%
#grouping values 
survey.groupby(['Past_Vote','age_group'])['response_id'].count()
# Out:
# Past_Vote     age_group
# BJP           18-25         863
#               25-40        1565
#               40-55         332
#               55+            63
# BSP           18-25           7
#               25-40           2
#               40-55           0
#               55+             0
# Did not vote  18-25         649
#               25-40         142
#               40-55           8
#               55+             5
# HAM           18-25          15
#               25-40          24
#               40-55           8
#               55+             3
# INC           18-25          62
#               25-40         114
#               40-55          32
#               55+             5
# JAP(L)        18-25          26
#               25-40          14
#               40-55           2
#               55+             0
# JD(U)         18-25         443
#               25-40         781
#               40-55         137
#               55+            13
# ...

# %%
#Create a dataframe by performing a group by over age_group and finding the count of total samples for each age_group that opted for the JD(U) party in Vote_Now.
t9=survey.groupby( [ "age_group",'Past_Vote'] ).size().to_frame(name = 'count').reset_index()

# %% [markdown]
# # from above we can see that count of total samples for each age_group that opted for the JD(U) party in Vote_Now is 1374

# %% [markdown]
# # 13.Join/Merge the two dataframes from questions 12 and 11 with the common column as age_group.

# %%
df_merge_col = pd.merge(t9, t5, on= 'age_group')

# %%
df_merge_col
# Out:
#    age_group     Past_Vote  count_x  count_y
# 0      18-25           BJP      863     2692
# 1      18-25           BSP        7     2692
# 2      18-25  Did not vote      649     2692
# 3      18-25           HAM       15     2692
# 4      18-25           INC       62     2692
# 5      18-25        JAP(L)       26     2692
# 6      18-25         JD(U)      443     2692
# 7      18-25           LJP       27     2692
# 8      18-25    Left Front        9     2692
# 9      18-25          NOTA       91     2692
# 10     18-25        Others       54     2692
# 11     18-25           RJD      435     2692
# 12     18-25          RLSP        9     2692
# 13     18-25           VIP        2     2692
# 14     25-40           BJP     1565     3423
# 15     25-40           BSP        2     3423
# 16     25-40  Did not vote      142     3423
# 17     25-40           HAM       24     3423
# 18     25-40           INC      114     3423
# 19     25-40        JAP(L)       14     3423
# ...
